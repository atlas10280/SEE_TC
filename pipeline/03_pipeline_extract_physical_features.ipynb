# %%
########## Dependencies
##### define input directory
tiff_path = "/mnt/local/data2/Bootsma/2D_CTC/src/analysis/publication_code/test_data/"

##### Libraries
import sys
sys.path.append('../src/') 
import SEE_TC as ctc

# %%
# define input
file_names = ctc.parse_nd2_paths(tiff_path, ".bias_corrected.tiff", recursive=True)
file_names = [s.replace(".bias_corrected.tiff", "") for s in file_names]
print(len(file_names), file_names[0])

# %%
##### correct instrument bias
for file_i in file_names:
    ctc.extract_features_biasCorrected_tiff(file_i)
